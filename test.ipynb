# %%
from taiwan_stock_calculator import InvalidPriceError, get_price_range, create_price_table

def color_text(text, color):
    colors = {
        'red': '\033[91m',
        'green': '\033[92m',
        'cyan': '\033[96m',
        'reset': '\033[0m'
    }
    return f"{colors.get(color, '')}{text}{colors['reset']}"

def print_table(headers, rows, column_widths=None):
    if column_widths is None:
        column_widths = [max(len(str(row[i])) for row in rows + [headers]) for i in range(len(headers))]
    
    header_line = "| " + " | ".join(header.ljust(width) for header, width in zip(headers, column_widths)) + " |"
    separator_line = "+" + "+".join("-" * (width + 2) for width in column_widths) + "+"
    
    print(separator_line)
    print(header_line)
    print(separator_line)
    
    for row in rows:
        row_str = "| " + " | ".join(str(item).ljust(width) for item, width in zip(row, column_widths)) + " |"
        print(row_str)
    
    print(separator_line)

def test_get_price_range():
    price_ranges = create_price_table()

    valid_cases = [
        (0.01, 0.01, 0.02),
        (0.02, 0.01, 0.03),
        (4.99, 4.98, 5.00),
        (5, 4.99, 5.01),
        (7.5, 7.49, 7.51),
        (9.99, 9.98, 10.00),
        (10, 9.99, 10.05),
        (25, 24.95, 25.05),
        (50, 49.95, 50.1),
        (75, 74.9, 75.1),
        (100, 99.9, 100.5),
        (125, 124.5, 125.5),
        (150, 149.5, 150.5),
        (300, 299.5, 300.5),
        (500, 499.5, 501.0),
        (750, 749.0, 751.0),
        (1000, 999.0, 1005.0),
        (1500, 1495.0, 1505.0),
        (10000, 9995.0, 10005.0),
    ]

    invalid_cases = [
        0, 0.001, 0.009, -1, -100, "not a number",
        1001, 1234, 9999, 1000000000, float("inf"),
        0.011111, 10.005, 100.0001,
        49.99, 99.99, 149.99, 499.99, 999.99,
    ]

    valid_results = []
    invalid_results = []

    print(color_text("Testing valid cases:", "cyan"))
    for price, expected_down, expected_up in valid_cases:
        try:
            down, up = get_price_range(price, price_ranges)
            status = "Passed" if down == expected_down and up == expected_up else "Failed"
            color = "green" if status == "Passed" else "red"
            valid_results.append([price, expected_down, expected_up, down, up, color_text(status, color)])
        except Exception as e:
            valid_results.append([price, expected_down, expected_up, "-", "-", color_text(f"Failed - {str(e)}", "red")])

    headers = ["Price", "Expected Down", "Expected Up", "Actual Down", "Actual Up", "Status"]
    print_table(headers, valid_results)

    print("\n" + color_text("Testing invalid cases:", "cyan"))
    for price in invalid_cases:
        try:
            get_price_range(price, price_ranges)
            invalid_results.append([price, color_text("Failed - Should have raised an error", "red")])
        except InvalidPriceError as e:
            invalid_results.append([price, color_text(f"Passed - {str(e)}", "green")])
        except Exception as e:
            invalid_results.append([price, color_text(f"Failed - Unexpected error: {str(e)}", "red")])

    headers = ["Price", "Status"]
    print_table(headers, invalid_results)

test_get_price_range()
# Out:
# Testing valid cases:
# +-------+---------------+-------------+-------------+-----------+-----------------+
# | Price | Expected Down | Expected Up | Actual Down | Actual Up | Status          |
# +-------+---------------+-------------+-------------+-----------+-----------------+
# | 0.01  | 0.01          | 0.02        | 0.01        | 0.02      | Passed |
# | 0.02  | 0.01          | 0.03        | 0.01        | 0.03      | Passed |
# | 4.99  | 4.98          | 5.0         | 4.98        | 5.0       | Passed |
# | 5     | 4.99          | 5.01        | 4.99        | 5.01      | Passed |
# | 7.5   | 7.49          | 7.51        | 7.49        | 7.51      | Passed |
# | 9.99  | 9.98          | 10.0        | 9.98        | 10.0      | Passed |
# | 10    | 9.99          | 10.05       | 9.99        | 10.05     | Passed |
# | 25    | 24.95         | 25.05       | 24.95       | 25.05     | Passed |
# | 50    | 49.95         | 50.1        | 49.95       | 50.1      | Passed |
# | 75    | 74.9          | 75.1        | 74.9        | 75.1      | Passed |
# | 100   | 99.9          | 100.5       | 99.9        | 100.5     | Passed |
# | 125   | 124.5         | 125.5       | 124.5       | 125.5     | Passed |
# | 150   | 149.5         | 150.5       | 149.5       | 150.5     | Passed |
# | 300   | 299.5         | 300.5       | 299.5       | 300.5     | Passed |
# | 500   | 499.5         | 501.0       | 499.5       | 501.0     | Passed |
# | 750   | 749.0         | 751.0       | 749.0       | 751.0     | Passed |
# | 1000  | 999.0         | 1005.0      | 999.0       | 1005.0    | Passed |
# | 1500  | 1495.0        | 1505.0      | 1495.0      | 1505.0    | Passed |
# | 10000 | 9995.0        | 10005.0     | 9995.0      | 10005.0   | Passed |
# +-------+---------------+-------------+-------------+-----------+-----------------+
#
# Testing invalid cases:
# +--------------+--------------------------------------------------------------------------------------+
# | Price        | Status                                                                               |
# +--------------+--------------------------------------------------------------------------------------+
# | 0            | Passed - Price 0.0 is not positive.                                         |
# | 0.001        | Passed - Price 0.001 is below the minimum allowed price of 0.01.            |
# | 0.009        | Passed - Price 0.009 is below the minimum allowed price of 0.01.            |
# | -1           | Passed - Price -1.0 is not positive.                                        |
# | -100         | Passed - Price -100.0 is not positive.                                      |
# | not a number | Passed - Invalid price input: not a number. Price must be a number.         |
# | 1001         | Passed - Price 1001.0 above 1000 must be an integer multiple of 5.          |
# | 1234         | Passed - Price 1234.0 above 1000 must be an integer multiple of 5.          |
# | 9999         | Passed - Price 9999.0 above 1000 must be an integer multiple of 5.          |
# | 1000000000   | Passed - Price 1000000000.0 exceeds the maximum allowed price of 1,000,000. |
# | inf          | Passed - Price inf exceeds the maximum allowed price of 1,000,000.          |
# | 0.011111     | Passed - Price 0.011111 in range 0.01-5 must have at most 2 decimal places. |
# | 10.005       | Passed - Price 10.005 in range 10-50 must be a multiple of 0.05.            |
# | 100.0001     | Passed - Price 100.0001 in range 100-500 must be a multiple of 0.5.         |
# | 49.99        | Passed - Price 49.99 in range 10-50 must be a multiple of 0.05.             |
# | 99.99        | Passed - Price 99.99 in range 50-100 must be a multiple of 0.1.             |
# | 149.99       | Passed - Price 149.99 in range 100-500 must be a multiple of 0.5.           |
# | 499.99       | Passed - Price 499.99 in range 100-500 must be a multiple of 0.5.           |
# | 999.99       | Passed - Price 999.99 in range 500-1000 must be an integer.                 |
# +--------------+--------------------------------------------------------------------------------------+
